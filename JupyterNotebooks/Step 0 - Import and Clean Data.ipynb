# %% [markdown]
# # Text Exploration

# %%
import sys
print(sys.version)
# Out:
# 3.6.3 |Anaconda custom (64-bit)| (default, Oct 15 2017, 03:27:45) [MSC v.1900 64 bit (AMD64)]

# %%
# Use AzureML's data collector to log various metrics!
#from azureml.logging import current_scriptrun
#logger = current_scriptrun()
# Use AzureML's data collector to log various metrics!
#from azureml.logging import current_scriptrun
#logger = current_scriptrun()

import string, re
import pandas as pd
from nltk.corpus import stopwords
from gensim import corpora, models, similarities
import azureml
from __future__ import division
import numpy as np
import nltk
from nltk.corpus import stopwords
from azure.storage.blob import BlockBlobService

# import libraries
from __future__ import print_function
import numpy as np
from six.moves import zip
import json
import warnings
import pandas as pd
from pandas import DataFrame   
import pickle
import re
import sys 
import azureml
import string
from scipy import stats
import pip
import keras
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.preprocessing.text import Tokenizer     
from keras.preprocessing import sequence
import os
import tempfile  
import logging
import gensim
from gensim.models import Phrases, phrases
from gensim.models.phrases import Phraser
from gensim.models import Word2Vec as wv
import nltk
from nltk.corpus import stopwords
from gensim import corpora, models, similarities
from IPython.display import SVG
import cloudpickle
import csv
import mkl
import matplotlib.pyplot as plt
import h5py
from keras.models import load_model
import re
import io
from os.path import dirname, join
import regex
import pandas as pd
from nltk.corpus import stopwords
from gensim import corpora, models, similarities
import azureml
from __future__ import division
import numpy as np
import nltk
from nltk.corpus import stopwords
# Out:
# C:\Users\kero5\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# C:\Users\kero5\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# Import source text and write to a pandas dataframe

# %%
import os
home_dir = 'C:/Users/kero5/Documents/UW/4B/ECE457B/StockPerformanceClassification'
bitcoin_prices = pd.read_csv(home_dir + '/Data/labels.csv')

texts = pd.read_csv(home_dir + '/Data/texts0.csv')
texts.append(pd.read_csv(home_dir + '/Data/texts1.csv', header=0))
texts.append(pd.read_csv(home_dir + '/Data/texts2.csv', header=0))
# Out:
#        time_day  num_posts                                          concatted
# 0    2016-04-04       1137   Where  your source for the fact that every co...
# 1    2015-12-28       2169   boils down  two issues 1 XT   client other th...
# 2    2015-08-15       1534   Fall  2014 the email that  used before disapp...
# 3    2015-04-27       1519  Thanks The Bitcoin blockchain itself doesn  su...
# 4    2016-07-31       1073  Over 1 5 hours now since  attempted  send BTC ...
# 5    2015-06-18       1629  How many bitcoin  that And can someone tell  w...
# 6    2016-11-15       1470   One reason ofcourse  the counterexample   btc...
# 7    2016-05-16       1119  Unstealable gold  more secure than hackable Bi...
# 8    2017-08-06       4470   fiat you find some that you forgot  your old ...
# 9    2016-12-11       1223  General answer Bitsquare  paxful com bitcoin  ...
# 10   2017-03-01       2685   now  significant percentage   portfolio   bit...
# 11   2017-09-05       4529  Bitcoin cash  bitcoin though Just because core...
# 12   2015-03-04       1384    Here   information   CVivien  CVivien has ta...
# 13   2015-10-18       1050   believe this speech  very telling   opinion J...
# 14   2015-12-03       1594  Someone did that    the blockchain Was reading...
# 15   2017-12-25       9486  Mostly Austrian economists  bitcoin   noticed ...
# 16   2016-06-09       1433   Read Hayek one  the key points  rule  law  eq...
# 17   2016-06-24       1778  Thats the point  isn  Bitcoin gets gamed  much...
# 18   2016-09-16       1047  Hey was curious  you could tell  your steam   ...
# 19   2015-02-05       2151  Probably the whole Reddit Notes thing has remi...
# 20   2015-08-20       2592  The Bitcoin tip for 1 high five 20 833 bits 5 ...
# 21   2015-06-05       1681  Because    well known endless contrarian and l...
# 22   2017-01-18       1817  Nice complete list  online casinos that accept...
# 23   2015-12-31       1646    you think Bitcoin needs Wall Street you   ba...
# 24   2017-01-17       1888  Videos  this bundle First self pee video  ever...
# 25   2015-05-19       1795   This post has been certified good for Bitcoin...
# 26   2015-11-08       1748   guess  don  know that much about bitcoin  don...
# 27   2015-06-01       2656  Some people like  have privacy for the sake  p...
# 28   2017-10-22       5235  His advice  that the price will drop and stay ...
# 29   2015-05-17       1188  Dude  the very beginning you could have contro...
# ..          ...        ...                                                ...
# 325  2015-11-26       1322  The Bitcoin Network which  all the hardware an...
# 326  2017-05-13       2492  Would   able  transfer Bitcoin from Coinbase  ...
# 327  2017-06-25       2357   Store  value Not with its current instability...
# 328  2017-10-29       5015  That’ not totally true You have  make sure tha...
# 329  2015-05-24       1279    Luckily  hang out with enough bitcoin people...
# 330  2015-12-27       1916   Author ceo  bitcoin Content  need  end the Bl...
# 331  2016-05-25       1305  Rootstock does not run  top  Bitcoin even thou...
# 332  2017-11-20       8522   think you  right  far   can tell the argument...
# 333  2016-04-29        938   LOLOLOL DAE BITCOINS XDDDDDD  WASN  PLAYING  ...
# 334  2016-10-03       1247  you can book  flight through expedia for bitco...
# 335  2016-08-26       1225  This  good news for bitcoin Snapshots This Pos...
# 336  2017-05-17       3252   Here  the link  the original comment thread  ...
# 337  2015-02-15       1550  That  nice Tell  why   wrong regarding Bitcoin...
# 338  2015-01-27       2009  They  embraced the volatility  bitcoin and now...
# 339  2015-03-28       1239  Translating email addresses  bitcoin addresses...
# 340  2015-11-19       1546  What   makes  law use Bitcoin goto jail kk  Wh...
# 341  2017-03-05       2078    attacker can rent 50  total hashpower  theor...
# 342  2016-05-30       1300  That sounds  easy Please tell  when bitcoin   ...
# 343  2015-08-29       1475   actually  not have any bitcoin  That  false B...
# 344  2015-05-31       1745    true that investors have the ultimate contro...
# 345  2015-10-15       1475   How about this myth Blockstream technology wi...
# 346  2017-06-10       2892  Jag ålde min ukulele till  kompis ör 10k bitco...
# 347  2017-11-12      11009  You are being naive People this community woul...
# 348  2015-01-24       1580  Good morning fellow Bitcoin traders   12 05 34...
# 349  2016-10-16       1326  Bonus tweeted pic with  bitcoin wallet Trezor ...
# 350  2015-11-23       1389  Amazing  see how far ahead Kenya   MPesa compa...
# 351  2016-03-08       1718  Added  Well actually they are finite Even more...
# 352  2017-03-14       3836  Anyone who thinks  aren  due for  correction c...
# 353  2015-02-09       2049  The most interesting thing about his comments ...
# 354  2017-12-16      10687  Bitcoin futures are going  gap  huge  Yes And ...
#
# [713 rows x 3 columns]

# %%
texts_subset = texts.sample(10)


def clean_text(row):
    # text = row['text'].decode('utf-8').lower()
    text = row['concatted'].lower()

    # Remove newline characters
    cleantext = text.replace('\r\n', ' ')

    # Convert HTML punctuation chaaracters
    cleantext = cleantext.replace(' www.', ' ')   
    cleantext = cleantext.replace('.com ', ' ')    
    cleantext = cleantext.replace('.', ' ')
    cleantext = cleantext.replace(',', ' ')
    cleantext = cleantext.replace('!', ' ')
    cleantext = cleantext.replace('$;', ' ')
    cleantext = cleantext.replace(';', ' ')
    cleantext = cleantext.replace(')', ' ')
    cleantext = cleantext.replace('(', ' ')   
    cleantext = cleantext.replace('>', ' ')  
    cleantext = cleantext.replace('<', ' ')  
    cleantext = cleantext.replace('-', ' ')  #take away hyphen and collapse hyphenated words
    cleantext = cleantext.replace(' the ', ' ')  
    cleantext = cleantext.replace(' of ', ' ')   
    cleantext = cleantext.replace(' in ', ' ')  
    cleantext = cleantext.replace(' and ', ' ')  
    cleantext = cleantext.replace(' by ', ' ')  
    cleantext = cleantext.replace(' to ', ' ')  
    cleantext = cleantext.replace(' at ', ' ')  
    cleantext = cleantext.replace(' on ', ' ') 
    cleantext = cleantext.replace(' for ', ' ')  
    cleantext = cleantext.replace(' be ', ' ')   
    cleantext = cleantext.replace(' is ', ' ')    
    cleantext = cleantext.replace(' or ', ' ')   
    cleantext = cleantext.replace(' we ', ' ')   
    cleantext = cleantext.replace(' that ', ' ')   
    cleantext = cleantext.replace(' our ', ' ')   
    cleantext = cleantext.replace(' as ', ' ')        
    cleantext = cleantext.replace(' from ', ' ')   
    cleantext = cleantext.replace(' are ', ' ')   
    cleantext = cleantext.replace(' with ', ' ')   
    cleantext = cleantext.replace(' us ', ' ')   
    cleantext = cleantext.replace(' was ', ' ')        
    cleantext = cleantext.replace(' this ', ' ')   
    cleantext = cleantext.replace(' an ', ' ')        
    cleantext = cleantext.replace(' by ', ' ')   
    cleantext = cleantext.replace(' sr ', ' ')      
    cleantext = cleantext.replace(' it ', ' ')  
    cleantext = cleantext.replace(' s ', ' ')
    
    # added in ECE457B
    cleantext = cleantext.replace(' you ', ' ') 
    cleantext = cleantext.replace(' they ', ' ')   
    cleantext = cleantext.replace(' your ', ' ')   


    #remove non alpha characters and specific noise
    cleantext = re.sub(r'\d+', ' ',cleantext)
    cleantext = re.sub(r'^b',' ',cleantext)
    cleantext = re.sub(r'[^\w]',' ',cleantext)
    cleantext = cleantext.replace('xc xs', ' ')  
    cleantext = cleantext.replace('xe xs', ' ')  
    cleantext = cleantext.replace('xc xS', ' ')  
    cleantext = cleantext.replace('xe xS', ' ')  
    cleantext = cleantext.replace('xc xa', ' ')  
    cleantext = cleantext.replace('xe xa', ' ')  
    cleantext = cleantext.replace(' xc xc x', ' ')  
    cleantext = cleantext.replace(' xc ', ' ')  
    cleantext = cleantext.replace(' xe ', ' ')  
    cleantext = cleantext.replace(' xs ', ' ')  
    cleantext = cleantext.replace(' xa ', ' ')  
    cleantext = cleantext.replace(' ct ', ' ')  
    cleantext = cleantext.replace(' x ', ' ')  
    cleantext = cleantext.replace(' non exclusive ', ' non-exclusive ') 
    cleantext = cleantext.replace(' u ', ' ')   
    cleantext = cleantext.replace(' s ', ' ')  
    
    #remove specific noise
    cleantext = cleantext.translate(str.maketrans({'‘':' ','’':' '}))
    cleantext = cleantext.translate(str.maketrans({',':' ',',':' '}))
    cleantext = cleantext.translate(str.maketrans({'[':' ',']':' '}))
    cleantext = cleantext.translate(str.maketrans({'"':' ','%':' '}))
    cleantext = cleantext.translate(str.maketrans({'^':' ','*':' '}))

    #remove punctuation
    punctpattern = re.compile('[%s]' % re.escape(string.punctuation))
    cleanttext = re.sub(punctpattern,'', cleantext)

    #remove single letter word
    cleantext = re.sub('(\\b[A-Za-z] \\b|\\b [A-Za-z]\\b)', '', cleantext) 

    # Remove extra spaces
    cleantext = re.sub('\s+', ' ', cleantext).strip()

    return cleantext

#apply regex fixes to the input text column
texts_subset['concatted'] = texts_subset.apply(clean_text, axis=1)
texts_subset.to_csv(home_dir + '//Data//cleaned_subset.csv', sep='\t', encoding='utf-8')

# %%
# tokenize, create seqs, pad
tok = Tokenizer(num_words=5000, lower=True, split=" ")
tok.fit_on_texts(texts_subset['concatted'])
tok.texts_to_sequences(texts_subset['concatted'])

import nltk 

nltk.download('punkt')
sent_lst = []

for doc in texts_subset['concatted']:
    sentences = nltk.tokenize.sent_tokenize(doc)
    for sent in sentences:
        word_lst = [w for w in nltk.tokenize.word_tokenize(sent) if w.isalnum()]
        sent_lst.append(word_lst)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kero5\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from gensim.models import Phrases
phrases = Phrases(texts_subset)
print(phrases)
# Out:
# Phrases<37 vocab, min_count=5, threshold=10.0, max_vocab_size=40000000>

# %%
# Create dictionary and save it
dictionary = corpora.Dictionary(sent_lst)
print(dictionary)
# Out:
# Dictionary(61907 unique tokens: ['a', 'aa', 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa', 'aaaaaaand', 'aaah']...)

# %%
dictionary.save('texts.dict')
print(dictionary)
# Out:
# Dictionary(61907 unique tokens: ['a', 'aa', 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa', 'aaaaaaand', 'aaah']...)

# %%
# Create tokenized corpus and save it
corpus = [dictionary.doc2bow(sent_lst) for sent_lst in sent_lst]
corpora.MmCorpus.serialize('texts.dict', corpus)

# %%
print(corpus[0])
# Out:
# [(0, 184), (1, 5), (2, 2), (3, 1), (4, 1), (5, 2), (6, 1), (7, 1), (8, 1), (9, 7), (10, 2), (11, 1), (12, 1), (13, 1), (14, 1), (15, 1), (16, 8), (17, 1), (18, 12), (19, 11), (20, 5), (21, 3), (22, 1), (23, 1), (24, 2), (25, 4), (26, 9), (27, 1), (28, 8), (29, 1), (30, 1), (31, 1), (32, 2), (33, 1), (34, 1), (35, 58), (36, 1), (37, 1), (38, 1), (39, 1), (40, 1), (41, 1), (42, 3), (43, 7), (44, 139), (45, 1), (46, 1), (47, 2), (48, 1), (49, 588), (50, 4), (51, 4), (52, 1), (53, 4), (54, 1), (55, 3), (56, 1), (57, 1), (58, 2), (59, 1), (60, 1), (61, 1), (62, 2), (63, 1), (64, 1), (65, 6), (66, 4445), (67, 266), (68, 3), (69, 1), (70, 1), (71, 8), (72, 1), (73, 2), (74, 4), (75, 1), (76, 1), (77, 1), (78, 42), (79, 232), (80, 1), (81, 2), (82, 1), (83, 9), (84, 4), (85, 11), (86, 1), (87, 12), (88, 2), (89, 1), (90, 2), (91, 1), (92, 2), (93, 46), (94, 1), (95, 8), (96, 1), (97, 1), (98, 1), (99, 2), (100, 21), (101, 5), (102, 3), (103, 2), (104, 1), (105, 1), (106, 1), (107, 1), (108, 1), (109, 6), (110, 1), (111, 2), (112, 9), (113, 2), (114, 1), (115, 1), (116, 1), (117, 6), (118, 1), (119, 9), (120, 2), (121, 2), (122, 1), (123, 1), (124, 12), (125, 2), (126, 334), (127, 1), (128, 18), (129, 25), (130, 1), (131, 115), (132, 143), (133, 177), (134, 1), (135, 1), (136, 258), (137, 1), (138, 11), (139, 2), (140, 30), (141, 15), (142, 3), (143, 12), (144, 2), (145, 18), (146, 3), (147, 1), (148, 6), (149, 1), (150, 1), (151, 2), (152, 2), (153, 3), (154, 17), (155, 5), (156, 1), (157,
.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=20, update_every=1, chunksize=1000, passes=5)

# %%
lda.print_topics(20)
# Out:
# [(0,
#   '0.017*"bitcoin" + 0.013*"have" + 0.009*"but" + 0.008*"will" + 0.007*"not" + 0.006*"can" + 0.006*"just" + 0.005*"there" + 0.005*"what" + 0.005*"don"'),
#  (1,
#   '0.019*"bitcoin" + 0.007*"but" + 0.006*"not" + 0.006*"can" + 0.006*"will" + 0.005*"just" + 0.005*"people" + 0.004*"have" + 0.004*"about" + 0.004*"has"'),
#  (2,
#   '0.018*"bitcoin" + 0.007*"can" + 0.006*"have" + 0.006*"but" + 0.005*"just" + 0.004*"not" + 0.004*"will" + 0.004*"all" + 0.004*"about" + 0.004*"people"'),
#  (3,
#   '0.024*"bitcoin" + 0.011*"can" + 0.009*"will" + 0.009*"not" + 0.007*"but" + 0.006*"have" + 0.005*"what" + 0.004*"all" + 0.004*"like" + 0.004*"about"'),
#  (4,
#   '0.021*"bitcoin" + 0.007*"have" + 0.007*"will" + 0.006*"but" + 0.006*"not" + 0.005*"can" + 0.004*"just" + 0.004*"here" + 0.004*"like" + 0.004*"has"'),
#  (5,
#   '0.020*"bitcoin" + 0.011*"not" + 0.008*"can" + 0.006*"but" + 0.006*"have" + 0.006*"just" + 0.006*"will" + 0.005*"about" + 0.004*"money" + 0.004*"more"'),
#  (6,
#   '0.022*"bitcoin" + 0.009*"have" + 0.008*"will" + 0.007*"but" + 0.006*"not" + 0.005*"what" + 0.005*"can" + 0.005*"people" + 0.004*"has" + 0.004*"like"'),
#  (7,
#   '0.014*"bitcoin" + 0.007*"not" + 0.006*"have" + 0.006*"will" + 0.006*"can" + 0.005*"but" + 0.003*"just" + 0.003*"people" + 0.003*"like" + 0.003*"here"'),
#  (8,
#   '0.033*"bitcoin" + 0.010*"not" + 0.010*"can" + 0.010*"have" + 0.010*"but" + 0.009*"will" + 0.006*"people" + 0.006*"just" + 0.006*"what" + 0.006*"like"'),
#  (9,
#   '0.016*"bitcoin" + 0.006*"not" + 0.006*"but" + 0.006*"can" + 0.006*"will" + 0.004*"more" + 0.004*"have" + 0.004*"what" + 0.003*"would" + 0.003*"all"'),
#  (10,
#   '0.014*"bitcoin" + 0.008*"can" + 0.006*"not" + 0.005*"have" + 0.005*"but" + 0.004*"will" + 0.004*"people" + 0.004*"like" + 0.003*"what" + 0.003*"all"'),
#  (11,
#   '0.013*"bitcoin" + 0.007*"not" + 0.005*"but" + 0.005*"like" + 0.005*"will" + 0.004*"can" + 0.004*"have" + 0.004*"people" + 0.003*"there" + 0.003*"just"'),
#  (12,
#   '0.010*"bitcoin" + 0.008*"not" + 0.006*"can" + 0.006*"but" + 0.005*"have" + 0.005*"will" + 0.004*"people" + 0.004*"what" + 0.004*"more" + 0.003*"all"'),
#  (13,
#   '0.018*"bitcoin" + 0.007*"can" + 0.006*"have" + 0.005*"will" + 0.005*"not" + 0.004*"but" + 0.004*"here" + 0.004*"there" + 0.004*"all" + 0.004*"what"'),
#  (14,
#   '0.029*"bitcoin" + 0.010*"will" + 0.009*"not" + 0.009*"but" + 0.009*"can" + 0.009*"have" + 0.007*"what" + 0.005*"there" + 0.005*"like" + 0.005*"more"'),
#  (15,
#   '0.032*"bitcoin" + 0.010*"not" + 0.009*"have" + 0.009*"can" + 0.009*"but" + 0.008*"will" + 0.006*"just" + 0.006*"people" + 0.006*"all" + 0.005*"there"'),
#  (16,
#   '0.028*"bitcoin" + 0.011*"not" + 0.010*"can" + 0.009*"have" + 0.009*"will" + 0.008*"but" + 0.006*"all" + 0.005*"what" + 0.005*"just" + 0.005*"more"'),
#  (17,
#   '0.021*"bitcoin" + 0.008*"not" + 0.008*"have" + 0.007*"can" + 0.007*"will" + 0.006*"but" + 0.006*"what" + 0.005*"just" + 0.005*"there" + 0.005*"about"'),
#  (18,
#   '0.017*"bitcoin" + 0.006*"not" + 0.006*"will" + 0.005*"but" + 0.005*"can" + 0.005*"have" + 0.004*"about" + 0.004*"like" + 0.004*"people" + 0.003*"more"'),
#  (19,
#   '0.026*"bitcoin" + 0.011*"can" + 0.009*"not" + 0.007*"have" + 0.007*"will" + 0.007*"but" + 0.006*"just" + 0.005*"what" + 0.005*"like" + 0.005*"all"')]

# %%
# Create index using LDA document projections
corpus_lda = lda[corpus]
index_lda = similarities.docsim.Similarity('index_lda.dat', corpus_lda, num_features=100)

# %%
print(index_lda)
# Out:
# Similarity index with 10 documents in 0 shards (stored under index_lda.dat)

# %%
# Return top 5 similar documents
index_lda.num_best = 20
index_lda[corpus_lda[1]]
# Out:
# [(1, 0.9999831914901733),
#  (2, 0.9924627542495728),
#  (8, 0.9570063352584839),
#  (4, 0.6782757043838501),
#  (7, 0.3452288806438446),
#  (9, 0.08505682647228241),
#  (6, 0.07102937996387482),
#  (5, 0.053025152534246445),
#  (0, 0.03551962971687317),
#  (3, 0.03337537497282028)]

# %%
print(corpus_lda[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-c7ae47974d4d> in <module>()
# ----> 1 print(corpus_lda[10])
#
# ~\Anaconda3\lib\site-packages\gensim\interfaces.py in __getitem__(self, docno)
#     213         """
#     214         if hasattr(self.corpus, '__getitem__'):
# --> 215             return self.obj[self.corpus[docno]]
#     216         else:
#     217             raise RuntimeError('Type {} does not support slicing.'.format(type(self.corpus)))
#
# IndexError: list index out of range

# %%
print(corpus_lda[128])
# Out:
# [(0, 0.04191737), (2, 0.012401357), (7, 0.40914482), (9, 0.0822838), (10, 0.011953827), (12, 0.042901862), (13, 0.011948517), (17, 0.38173416)]

# %%
# Create index using TFIDF document weights
index_tfidf = similarities.docsim.Similarity('index_tfidf.dat', corpus_tfidf, num_features=len(dictionary))

# %%
# Return top 5 similar documents
index_tfidf.num_best = 5
index_tfidf[corpus_tfidf[0]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-45b25e671ff4> in <module>()
#       1 # Return top 5 similar documents
# ----> 2 index_tfidf.num_best = 5
#       3 index_tfidf[corpus_tfidf[0]]
#
# NameError: name 'index_tfidf' is not defined

# %%
print(texts_subsets[172])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-c8b3c3ed8db0> in <module>()
# ----> 1 print(texts_subsets[172])
#
# NameError: name 'texts_subsets' is not defined

# %%
print(documents[173])
